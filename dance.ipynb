# %%
import socket
import cv2
import mediapipe as mp
import json
import numpy as np

# Initialize MediaPipe
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Open webcam
cap = cv2.VideoCapture(0)

# Create UDP socket
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
server_address = ('127.0.0.1', 5050)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Flip frame to mirror image
    frame = cv2.flip(frame, 1)

    # Original feed for the left side
    original = frame.copy()

    # Black image for the skeleton side
    skeleton = np.zeros_like(frame)

    # Convert to RGB
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb)

    data = {}

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark
        key_indices = [0, 11, 12, 13, 14, 23, 24]  # Nose, shoulders, elbows, hips

        for idx in key_indices:
            lm = landmarks[idx]
            data[str(idx)] = {'x': lm.x, 'y': lm.y, 'z': lm.z}
            print(f"Joint {idx}: x={lm.x:.2f}, y={lm.y:.2f}, z={lm.z:.2f}")

        # Send JSON to Unity
        message = json.dumps(data).encode()
        sock.sendto(message, server_address)
        print("Data sent to Unity 🚀")

        # Draw pose landmarks on the black image
        mp_drawing.draw_landmarks(
            skeleton,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=2)
        )
    else:
        print("❌ Pose not detected")

    # Combine both views side-by-side
    combined = np.hstack((original, skeleton))

    # Show the result
    cv2.imshow("You (Left) vs Skeleton (Right)", combined)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
sock.close()
# Out:
# ❌ Pose not detected
# ❌ Pose not detected
# ❌ Pose not detected
# ❌ Pose not detected
# ❌ Pose not detected
# ❌ Pose not detected
# Joint 0: x=0.42, y=0.90, z=-0.50
# Joint 11: x=0.66, y=0.92, z=-0.27
# Joint 12: x=0.40, y=0.97, z=0.08
# Joint 13: x=0.73, y=1.14, z=-0.56
# Joint 14: x=0.33, y=1.11, z=0.01
# Joint 23: x=0.71, y=1.56, z=-0.16
# Joint 24: x=0.49, y=1.57, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.90, z=-0.64
# Joint 11: x=0.65, y=0.93, z=-0.48
# Joint 12: x=0.36, y=0.98, z=-0.05
# Joint 13: x=0.72, y=1.19, z=-0.68
# Joint 14: x=0.27, y=1.13, z=0.05
# Joint 23: x=0.66, y=1.59, z=-0.16
# Joint 24: x=0.44, y=1.60, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.90, z=-0.73
# Joint 11: x=0.66, y=0.93, z=-0.49
# Joint 12: x=0.36, y=0.98, z=-0.17
# Joint 13: x=0.75, y=1.19, z=-0.67
# Joint 14: x=0.26, y=1.13, z=-0.21
# Joint 23: x=0.66, y=1.57, z=-0.13
# Joint 24: x=0.44, y=1.59, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.90, z=-0.56
# Joint 11: x=0.66, y=0.93, z=-0.42
# Joint 12: x=0.36, y=0.97, z=-0.09
# Joint 13: x=0.75, y=1.19, z=-0.57
# Joint 14: x=0.27, y=1.13, z=-0.01
# Joint 23: x=0.67, y=1.55, z=-0.15
# Joint 24: x=0.44, y=1.56, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.90, z=-0.79
# Joint 11: x=0.66, y=0.94, z=-0.50
# Joint 12: x=0.34, y=0.98, z=-0.15
# Joint 13: x=0.75, y=1.23, z=-0.75
# Joint 14: x=0.24, y=1.14, z=-0.10
# Joint 23: x=0.64, y=1.58, z=-0.15
# Joint 24: x=0.42, y=1.59, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-0.55
# Joint 11: x=0.66, y=0.94, z=-0.26
# Joint 12: x=0.35, y=0.98, z=0.00
# Joint 13: x=0.75, y=1.21, z=-0.51
# Joint 14: x=0.24, y=1.13, z=-0.08
# Joint 23: x=0.65, y=1.57, z=-0.13
# Joint 24: x=0.43, y=1.58, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.89, z=-0.78
# Joint 11: x=0.66, y=0.94, z=-0.48
# Joint 12: x=0.34, y=0.99, z=-0.16
# Joint 13: x=0.75, y=1.18, z=-0.53
# Joint 14: x=0.24, y=1.13, z=-0.07
# Joint 23: x=0.65, y=1.59, z=-0.16
# Joint 24: x=0.43, y=1.59, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.89, z=-1.01
# Joint 11: x=0.66, y=0.94, z=-0.62
# Joint 12: x=0.35, y=0.99, z=-0.33
# Joint 13: x=0.75, y=1.13, z=-0.58
# Joint 14: x=0.22, y=1.14, z=-0.12
# Joint 23: x=0.63, y=1.62, z=-0.16
# Joint 24: x=0.43, y=1.61, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.89, z=-0.88
# Joint 11: x=0.65, y=0.94, z=-0.57
# Joint 12: x=0.34, y=1.00, z=-0.24
# Joint 13: x=0.75, y=1.13, z=-0.61
# Joint 14: x=0.21, y=1.15, z=-0.11
# Joint 23: x=0.63, y=1.62, z=-0.17
# Joint 24: x=0.43, y=1.62, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.89, z=-0.85
# Joint 11: x=0.65, y=0.95, z=-0.52
# Joint 12: x=0.34, y=1.00, z=-0.19
# Joint 13: x=0.74, y=1.15, z=-0.71
# Joint 14: x=0.20, y=1.15, z=-0.10
# Joint 23: x=0.63, y=1.65, z=-0.18
# Joint 24: x=0.43, y=1.65, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-0.80
# Joint 11: x=0.65, y=0.95, z=-0.50
# Joint 12: x=0.34, y=1.00, z=-0.17
# Joint 13: x=0.74, y=1.12, z=-0.67
# Joint 14: x=0.21, y=1.14, z=0.06
# Joint 23: x=0.63, y=1.64, z=-0.18
# Joint 24: x=0.43, y=1.64, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-0.85
# Joint 11: x=0.65, y=0.95, z=-0.54
# Joint 12: x=0.34, y=1.00, z=-0.22
# Joint 13: x=0.73, y=1.12, z=-0.61
# Joint 14: x=0.21, y=1.14, z=0.02
# Joint 23: x=0.63, y=1.65, z=-0.18
# Joint 24: x=0.43, y=1.64, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.90, z=-0.84
# Joint 11: x=0.65, y=0.95, z=-0.48
# Joint 12: x=0.34, y=1.00, z=-0.20
# Joint 13: x=0.73, y=1.13, z=-0.57
# Joint 14: x=0.21, y=1.14, z=0.04
# Joint 23: x=0.63, y=1.68, z=-0.17
# Joint 24: x=0.43, y=1.67, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.91, z=-1.00
# Joint 11: x=0.65, y=0.95, z=-0.56
# Joint 12: x=0.35, y=1.07, z=-0.37
# Joint 13: x=0.73, y=1.08, z=-0.47
# Joint 14: x=0.22, y=1.15, z=-0.09
# Joint 23: x=0.63, y=1.68, z=-0.16
# Joint 24: x=0.45, y=1.67, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.91, z=-0.99
# Joint 11: x=0.65, y=0.96, z=-0.61
# Joint 12: x=0.35, y=1.09, z=-0.34
# Joint 13: x=0.74, y=1.13, z=-0.70
# Joint 14: x=0.22, y=1.16, z=-0.08
# Joint 23: x=0.63, y=1.70, z=-0.16
# Joint 24: x=0.45, y=1.68, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.91, z=-0.95
# Joint 11: x=0.65, y=0.95, z=-0.53
# Joint 12: x=0.35, y=1.08, z=-0.24
# Joint 13: x=0.73, y=1.11, z=-0.49
# Joint 14: x=0.23, y=1.17, z=-0.00
# Joint 23: x=0.64, y=1.69, z=-0.17
# Joint 24: x=0.45, y=1.68, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-1.05
# Joint 11: x=0.65, y=0.95, z=-0.63
# Joint 12: x=0.35, y=1.08, z=-0.41
# Joint 13: x=0.72, y=1.11, z=-0.52
# Joint 14: x=0.22, y=1.18, z=-0.13
# Joint 23: x=0.64, y=1.69, z=-0.16
# Joint 24: x=0.44, y=1.67, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-1.09
# Joint 11: x=0.65, y=0.95, z=-0.67
# Joint 12: x=0.34, y=1.08, z=-0.45
# Joint 13: x=0.72, y=1.11, z=-0.54
# Joint 14: x=0.22, y=1.18, z=-0.19
# Joint 23: x=0.63, y=1.68, z=-0.16
# Joint 24: x=0.43, y=1.67, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-1.01
# Joint 11: x=0.65, y=0.96, z=-0.63
# Joint 12: x=0.34, y=1.06, z=-0.43
# Joint 13: x=0.73, y=1.11, z=-0.59
# Joint 14: x=0.22, y=1.18, z=-0.11
# Joint 23: x=0.63, y=1.68, z=-0.17
# Joint 24: x=0.43, y=1.67, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-0.99
# Joint 11: x=0.65, y=0.96, z=-0.61
# Joint 12: x=0.34, y=1.06, z=-0.34
# Joint 13: x=0.73, y=1.14, z=-0.65
# Joint 14: x=0.20, y=1.17, z=-0.15
# Joint 23: x=0.63, y=1.68, z=-0.17
# Joint 24: x=0.43, y=1.67, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-0.90
# Joint 11: x=0.65, y=0.96, z=-0.60
# Joint 12: x=0.35, y=1.06, z=-0.25
# Joint 13: x=0.74, y=1.18, z=-0.74
# Joint 14: x=0.20, y=1.17, z=-0.14
# Joint 23: x=0.64, y=1.68, z=-0.18
# Joint 24: x=0.43, y=1.67, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-0.99
# Joint 11: x=0.65, y=0.96, z=-0.61
# Joint 12: x=0.35, y=1.06, z=-0.30
# Joint 13: x=0.73, y=1.14, z=-0.65
# Joint 14: x=0.21, y=1.16, z=-0.13
# Joint 23: x=0.64, y=1.68, z=-0.18
# Joint 24: x=0.43, y=1.67, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-0.99
# Joint 11: x=0.66, y=0.97, z=-0.60
# Joint 12: x=0.35, y=1.09, z=-0.30
# Joint 13: x=0.73, y=1.14, z=-0.64
# Joint 14: x=0.20, y=1.16, z=-0.12
# Joint 23: x=0.64, y=1.71, z=-0.18
# Joint 24: x=0.43, y=1.69, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-0.93
# Joint 11: x=0.66, y=0.97, z=-0.56
# Joint 12: x=0.35, y=1.09, z=-0.22
# Joint 13: x=0.73, y=1.14, z=-0.64
# Joint 14: x=0.20, y=1.16, z=-0.12
# Joint 23: x=0.64, y=1.71, z=-0.18
# Joint 24: x=0.43, y=1.70, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.90, z=-0.82
# Joint 11: x=0.65, y=0.97, z=-0.50
# Joint 12: x=0.35, y=1.09, z=-0.13
# Joint 13: x=0.73, y=1.17, z=-0.64
# Joint 14: x=0.20, y=1.17, z=0.05
# Joint 23: x=0.63, y=1.71, z=-0.18
# Joint 24: x=0.43, y=1.70, z=0.19
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.90, z=-0.82
# Joint 11: x=0.66, y=0.96, z=-0.51
# Joint 12: x=0.35, y=1.07, z=-0.17
# Joint 13: x=0.73, y=1.13, z=-0.53
# Joint 14: x=0.21, y=1.16, z=0.00
# Joint 23: x=0.64, y=1.66, z=-0.17
# Joint 24: x=0.43, y=1.66, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.90, z=-0.83
# Joint 11: x=0.66, y=0.96, z=-0.52
# Joint 12: x=0.35, y=1.07, z=-0.19
# Joint 13: x=0.74, y=1.14, z=-0.55
# Joint 14: x=0.21, y=1.16, z=0.01
# Joint 23: x=0.64, y=1.66, z=-0.17
# Joint 24: x=0.43, y=1.66, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.91, z=-0.80
# Joint 11: x=0.66, y=0.96, z=-0.43
# Joint 12: x=0.35, y=1.08, z=-0.11
# Joint 13: x=0.74, y=1.12, z=-0.51
# Joint 14: x=0.20, y=1.16, z=0.03
# Joint 23: x=0.64, y=1.69, z=-0.18
# Joint 24: x=0.43, y=1.69, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.91, z=-0.91
# Joint 11: x=0.66, y=0.96, z=-0.52
# Joint 12: x=0.36, y=1.08, z=-0.17
# Joint 13: x=0.74, y=1.16, z=-0.55
# Joint 14: x=0.21, y=1.16, z=0.04
# Joint 23: x=0.64, y=1.69, z=-0.18
# Joint 24: x=0.44, y=1.68, z=0.19
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.91, z=-0.95
# Joint 11: x=0.67, y=0.96, z=-0.57
# Joint 12: x=0.36, y=1.08, z=-0.20
# Joint 13: x=0.75, y=1.19, z=-0.69
# Joint 14: x=0.21, y=1.16, z=0.05
# Joint 23: x=0.65, y=1.69, z=-0.18
# Joint 24: x=0.44, y=1.68, z=0.19
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.92, z=-1.02
# Joint 11: x=0.67, y=0.97, z=-0.59
# Joint 12: x=0.35, y=1.09, z=-0.24
# Joint 13: x=0.77, y=1.21, z=-0.83
# Joint 14: x=0.21, y=1.18, z=0.03
# Joint 23: x=0.65, y=1.70, z=-0.19
# Joint 24: x=0.43, y=1.69, z=0.19
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.92, z=-1.01
# Joint 11: x=0.67, y=0.97, z=-0.63
# Joint 12: x=0.35, y=1.09, z=-0.32
# Joint 13: x=0.76, y=1.20, z=-0.77
# Joint 14: x=0.23, y=1.18, z=0.02
# Joint 23: x=0.65, y=1.71, z=-0.17
# Joint 24: x=0.44, y=1.69, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.92, z=-0.99
# Joint 11: x=0.67, y=0.97, z=-0.61
# Joint 12: x=0.36, y=1.09, z=-0.30
# Joint 13: x=0.76, y=1.19, z=-0.73
# Joint 14: x=0.24, y=1.18, z=0.04
# Joint 23: x=0.66, y=1.72, z=-0.17
# Joint 24: x=0.44, y=1.70, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.92, z=-0.98
# Joint 11: x=0.67, y=0.98, z=-0.52
# Joint 12: x=0.33, y=1.11, z=-0.22
# Joint 13: x=0.77, y=1.22, z=-0.92
# Joint 14: x=0.23, y=1.20, z=-0.13
# Joint 23: x=0.65, y=1.74, z=-0.17
# Joint 24: x=0.41, y=1.74, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.91, z=-0.89
# Joint 11: x=0.66, y=0.96, z=-0.53
# Joint 12: x=0.35, y=1.08, z=-0.20
# Joint 13: x=0.74, y=1.15, z=-0.67
# Joint 14: x=0.24, y=1.17, z=0.02
# Joint 23: x=0.65, y=1.72, z=-0.17
# Joint 24: x=0.42, y=1.70, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.91, z=-0.78
# Joint 11: x=0.66, y=0.96, z=-0.49
# Joint 12: x=0.35, y=1.08, z=-0.11
# Joint 13: x=0.74, y=1.14, z=-0.67
# Joint 14: x=0.24, y=1.16, z=0.18
# Joint 23: x=0.65, y=1.72, z=-0.18
# Joint 24: x=0.43, y=1.70, z=0.19
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.91, z=-0.83
# Joint 11: x=0.65, y=0.96, z=-0.50
# Joint 12: x=0.34, y=1.09, z=-0.14
# Joint 13: x=0.74, y=1.14, z=-0.68
# Joint 14: x=0.22, y=1.17, z=0.11
# Joint 23: x=0.64, y=1.74, z=-0.18
# Joint 24: x=0.42, y=1.73, z=0.19
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-0.45
# Joint 11: x=0.65, y=0.94, z=-0.19
# Joint 12: x=0.34, y=1.08, z=0.12
# Joint 13: x=0.74, y=1.12, z=-0.35
# Joint 14: x=0.22, y=1.15, z=0.16
# Joint 23: x=0.64, y=1.70, z=-0.18
# Joint 24: x=0.42, y=1.70, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-0.68
# Joint 11: x=0.65, y=0.94, z=-0.36
# Joint 12: x=0.34, y=1.08, z=0.02
# Joint 13: x=0.74, y=1.10, z=-0.45
# Joint 14: x=0.22, y=1.15, z=0.06
# Joint 23: x=0.64, y=1.71, z=-0.16
# Joint 24: x=0.42, y=1.70, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-0.63
# Joint 11: x=0.65, y=0.94, z=-0.35
# Joint 12: x=0.34, y=1.08, z=0.02
# Joint 13: x=0.74, y=1.11, z=-0.50
# Joint 14: x=0.22, y=1.17, z=0.14
# Joint 23: x=0.64, y=1.71, z=-0.17
# Joint 24: x=0.42, y=1.70, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-0.94
# Joint 11: x=0.65, y=1.02, z=-0.53
# Joint 12: x=0.32, y=1.08, z=-0.22
# Joint 13: x=0.74, y=1.16, z=-0.65
# Joint 14: x=0.21, y=1.17, z=0.10
# Joint 23: x=0.61, y=1.72, z=-0.16
# Joint 24: x=0.40, y=1.70, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-1.06
# Joint 11: x=0.64, y=1.05, z=-0.59
# Joint 12: x=0.30, y=1.08, z=-0.33
# Joint 13: x=0.74, y=1.17, z=-0.68
# Joint 14: x=0.20, y=1.18, z=0.05
# Joint 23: x=0.59, y=1.73, z=-0.15
# Joint 24: x=0.38, y=1.71, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.90, z=-1.08
# Joint 11: x=0.64, y=0.98, z=-0.61
# Joint 12: x=0.31, y=1.07, z=-0.40
# Joint 13: x=0.72, y=1.08, z=-0.54
# Joint 14: x=0.20, y=1.15, z=-0.12
# Joint 23: x=0.60, y=1.71, z=-0.15
# Joint 24: x=0.39, y=1.68, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.23
# Joint 11: x=0.64, y=0.96, z=-0.72
# Joint 12: x=0.31, y=1.07, z=-0.50
# Joint 13: x=0.72, y=1.09, z=-0.60
# Joint 14: x=0.20, y=1.15, z=-0.12
# Joint 23: x=0.60, y=1.71, z=-0.15
# Joint 24: x=0.40, y=1.68, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.25
# Joint 11: x=0.64, y=0.96, z=-0.74
# Joint 12: x=0.31, y=1.07, z=-0.51
# Joint 13: x=0.72, y=1.10, z=-0.65
# Joint 14: x=0.20, y=1.15, z=-0.12
# Joint 23: x=0.61, y=1.71, z=-0.15
# Joint 24: x=0.40, y=1.68, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.33
# Joint 11: x=0.65, y=0.95, z=-0.85
# Joint 12: x=0.31, y=1.06, z=-0.69
# Joint 13: x=0.71, y=1.08, z=-0.68
# Joint 14: x=0.20, y=1.14, z=-0.38
# Joint 23: x=0.61, y=1.69, z=-0.14
# Joint 24: x=0.40, y=1.66, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.91, z=-1.18
# Joint 11: x=0.65, y=0.95, z=-0.76
# Joint 12: x=0.32, y=1.08, z=-0.51
# Joint 13: x=0.73, y=1.13, z=-0.64
# Joint 14: x=0.20, y=1.17, z=-0.22
# Joint 23: x=0.61, y=1.72, z=-0.14
# Joint 24: x=0.40, y=1.70, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.91, z=-1.19
# Joint 11: x=0.65, y=0.96, z=-0.70
# Joint 12: x=0.32, y=1.10, z=-0.46
# Joint 13: x=0.74, y=1.16, z=-0.64
# Joint 14: x=0.20, y=1.19, z=-0.20
# Joint 23: x=0.61, y=1.73, z=-0.14
# Joint 24: x=0.40, y=1.72, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.30
# Joint 11: x=0.65, y=0.96, z=-0.81
# Joint 12: x=0.31, y=1.09, z=-0.52
# Joint 13: x=0.75, y=1.19, z=-0.89
# Joint 14: x=0.17, y=1.18, z=-0.25
# Joint 23: x=0.61, y=1.74, z=-0.15
# Joint 24: x=0.39, y=1.72, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.22
# Joint 11: x=0.65, y=0.96, z=-0.81
# Joint 12: x=0.31, y=1.09, z=-0.43
# Joint 13: x=0.75, y=1.18, z=-0.80
# Joint 14: x=0.17, y=1.16, z=-0.19
# Joint 23: x=0.61, y=1.75, z=-0.17
# Joint 24: x=0.40, y=1.73, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.12
# Joint 11: x=0.65, y=0.96, z=-0.69
# Joint 12: x=0.31, y=1.09, z=-0.34
# Joint 13: x=0.75, y=1.18, z=-0.74
# Joint 14: x=0.18, y=1.15, z=-0.15
# Joint 23: x=0.62, y=1.75, z=-0.18
# Joint 24: x=0.40, y=1.73, z=0.18
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.19
# Joint 11: x=0.65, y=0.96, z=-0.69
# Joint 12: x=0.31, y=1.09, z=-0.44
# Joint 13: x=0.75, y=1.18, z=-0.70
# Joint 14: x=0.18, y=1.15, z=-0.21
# Joint 23: x=0.62, y=1.75, z=-0.17
# Joint 24: x=0.40, y=1.73, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.18
# Joint 11: x=0.65, y=0.96, z=-0.72
# Joint 12: x=0.33, y=1.07, z=-0.50
# Joint 13: x=0.73, y=1.12, z=-0.65
# Joint 14: x=0.18, y=1.12, z=-0.32
# Joint 23: x=0.63, y=1.73, z=-0.17
# Joint 24: x=0.42, y=1.69, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.18
# Joint 11: x=0.66, y=0.96, z=-0.71
# Joint 12: x=0.33, y=1.07, z=-0.48
# Joint 13: x=0.73, y=1.12, z=-0.64
# Joint 14: x=0.18, y=1.12, z=-0.24
# Joint 23: x=0.63, y=1.73, z=-0.17
# Joint 24: x=0.43, y=1.69, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.21
# Joint 11: x=0.66, y=0.96, z=-0.76
# Joint 12: x=0.33, y=1.07, z=-0.52
# Joint 13: x=0.73, y=1.12, z=-0.70
# Joint 14: x=0.18, y=1.13, z=-0.25
# Joint 23: x=0.63, y=1.74, z=-0.17
# Joint 24: x=0.42, y=1.70, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.93, z=-1.45
# Joint 11: x=0.65, y=1.09, z=-0.86
# Joint 12: x=0.30, y=1.11, z=-0.64
# Joint 13: x=0.73, y=1.20, z=-0.85
# Joint 14: x=0.18, y=1.21, z=-0.25
# Joint 23: x=0.59, y=1.79, z=-0.16
# Joint 24: x=0.39, y=1.75, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.93, z=-1.38
# Joint 11: x=0.64, y=1.06, z=-0.80
# Joint 12: x=0.29, y=1.10, z=-0.67
# Joint 13: x=0.71, y=1.19, z=-0.72
# Joint 14: x=0.20, y=1.20, z=-0.43
# Joint 23: x=0.58, y=1.78, z=-0.13
# Joint 24: x=0.38, y=1.74, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.92, z=-1.32
# Joint 11: x=0.64, y=1.07, z=-0.77
# Joint 12: x=0.28, y=1.10, z=-0.64
# Joint 13: x=0.71, y=1.20, z=-0.70
# Joint 14: x=0.19, y=1.20, z=-0.26
# Joint 23: x=0.56, y=1.78, z=-0.14
# Joint 24: x=0.37, y=1.74, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.31
# Joint 11: x=0.63, y=1.07, z=-0.76
# Joint 12: x=0.28, y=1.09, z=-0.67
# Joint 13: x=0.71, y=1.18, z=-0.60
# Joint 14: x=0.19, y=1.19, z=-0.41
# Joint 23: x=0.56, y=1.77, z=-0.12
# Joint 24: x=0.36, y=1.74, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.31
# Joint 11: x=0.64, y=1.06, z=-0.75
# Joint 12: x=0.28, y=1.07, z=-0.61
# Joint 13: x=0.70, y=1.16, z=-0.61
# Joint 14: x=0.18, y=1.17, z=-0.40
# Joint 23: x=0.56, y=1.76, z=-0.12
# Joint 24: x=0.37, y=1.72, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.29
# Joint 11: x=0.64, y=1.06, z=-0.72
# Joint 12: x=0.28, y=1.07, z=-0.59
# Joint 13: x=0.70, y=1.15, z=-0.60
# Joint 14: x=0.17, y=1.15, z=-0.37
# Joint 23: x=0.56, y=1.77, z=-0.13
# Joint 24: x=0.37, y=1.73, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.45
# Joint 11: x=0.63, y=1.07, z=-0.80
# Joint 12: x=0.27, y=1.07, z=-0.67
# Joint 13: x=0.71, y=1.20, z=-0.79
# Joint 14: x=0.16, y=1.16, z=-0.36
# Joint 23: x=0.54, y=1.77, z=-0.13
# Joint 24: x=0.34, y=1.73, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.42
# Joint 11: x=0.62, y=1.10, z=-0.73
# Joint 12: x=0.26, y=1.07, z=-0.64
# Joint 13: x=0.70, y=1.22, z=-0.76
# Joint 14: x=0.16, y=1.16, z=-0.44
# Joint 23: x=0.53, y=1.79, z=-0.13
# Joint 24: x=0.33, y=1.74, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.25
# Joint 11: x=0.63, y=1.08, z=-0.70
# Joint 12: x=0.27, y=1.06, z=-0.62
# Joint 13: x=0.70, y=1.21, z=-0.64
# Joint 14: x=0.18, y=1.16, z=-0.40
# Joint 23: x=0.54, y=1.79, z=-0.13
# Joint 24: x=0.33, y=1.74, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.23
# Joint 11: x=0.63, y=1.08, z=-0.70
# Joint 12: x=0.27, y=1.06, z=-0.62
# Joint 13: x=0.70, y=1.20, z=-0.64
# Joint 14: x=0.17, y=1.16, z=-0.38
# Joint 23: x=0.54, y=1.79, z=-0.13
# Joint 24: x=0.34, y=1.74, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.07
# Joint 11: x=0.63, y=1.09, z=-0.54
# Joint 12: x=0.27, y=1.09, z=-0.33
# Joint 13: x=0.72, y=1.23, z=-0.71
# Joint 14: x=0.15, y=1.18, z=-0.26
# Joint 23: x=0.54, y=1.81, z=-0.15
# Joint 24: x=0.34, y=1.78, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.41
# Joint 11: x=0.63, y=1.09, z=-0.73
# Joint 12: x=0.26, y=1.09, z=-0.58
# Joint 13: x=0.72, y=1.22, z=-0.72
# Joint 14: x=0.15, y=1.16, z=-0.26
# Joint 23: x=0.53, y=1.81, z=-0.15
# Joint 24: x=0.33, y=1.77, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.26
# Joint 11: x=0.64, y=1.09, z=-0.70
# Joint 12: x=0.26, y=1.09, z=-0.51
# Joint 13: x=0.74, y=1.26, z=-0.74
# Joint 14: x=0.14, y=1.17, z=-0.20
# Joint 23: x=0.54, y=1.81, z=-0.15
# Joint 24: x=0.33, y=1.77, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.26
# Joint 11: x=0.65, y=1.09, z=-0.70
# Joint 12: x=0.26, y=1.09, z=-0.51
# Joint 13: x=0.75, y=1.26, z=-0.74
# Joint 14: x=0.14, y=1.18, z=-0.20
# Joint 23: x=0.55, y=1.81, z=-0.15
# Joint 24: x=0.33, y=1.77, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.34
# Joint 11: x=0.64, y=1.10, z=-0.71
# Joint 12: x=0.26, y=1.09, z=-0.58
# Joint 13: x=0.74, y=1.25, z=-0.75
# Joint 14: x=0.15, y=1.18, z=-0.25
# Joint 23: x=0.54, y=1.82, z=-0.15
# Joint 24: x=0.33, y=1.77, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.34
# Joint 11: x=0.64, y=1.10, z=-0.72
# Joint 12: x=0.26, y=1.10, z=-0.60
# Joint 13: x=0.74, y=1.25, z=-0.70
# Joint 14: x=0.15, y=1.19, z=-0.25
# Joint 23: x=0.54, y=1.82, z=-0.14
# Joint 24: x=0.33, y=1.77, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.35
# Joint 11: x=0.64, y=1.10, z=-0.74
# Joint 12: x=0.26, y=1.09, z=-0.59
# Joint 13: x=0.74, y=1.24, z=-0.74
# Joint 14: x=0.15, y=1.19, z=-0.26
# Joint 23: x=0.54, y=1.82, z=-0.15
# Joint 24: x=0.33, y=1.77, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.23
# Joint 11: x=0.64, y=1.10, z=-0.66
# Joint 12: x=0.26, y=1.09, z=-0.51
# Joint 13: x=0.74, y=1.25, z=-0.69
# Joint 14: x=0.15, y=1.19, z=-0.15
# Joint 23: x=0.54, y=1.82, z=-0.15
# Joint 24: x=0.33, y=1.77, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.33
# Joint 11: x=0.64, y=1.11, z=-0.74
# Joint 12: x=0.26, y=1.11, z=-0.52
# Joint 13: x=0.74, y=1.24, z=-0.81
# Joint 14: x=0.15, y=1.19, z=-0.11
# Joint 23: x=0.54, y=1.83, z=-0.15
# Joint 24: x=0.33, y=1.78, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.37
# Joint 11: x=0.64, y=1.11, z=-0.78
# Joint 12: x=0.26, y=1.11, z=-0.55
# Joint 13: x=0.74, y=1.24, z=-0.85
# Joint 14: x=0.15, y=1.19, z=-0.13
# Joint 23: x=0.55, y=1.84, z=-0.15
# Joint 24: x=0.34, y=1.78, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.41
# Joint 11: x=0.65, y=1.11, z=-0.81
# Joint 12: x=0.26, y=1.11, z=-0.58
# Joint 13: x=0.74, y=1.24, z=-0.88
# Joint 14: x=0.15, y=1.19, z=-0.16
# Joint 23: x=0.55, y=1.84, z=-0.15
# Joint 24: x=0.34, y=1.79, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.40
# Joint 11: x=0.64, y=1.11, z=-0.79
# Joint 12: x=0.26, y=1.11, z=-0.59
# Joint 13: x=0.74, y=1.24, z=-0.73
# Joint 14: x=0.15, y=1.19, z=-0.25
# Joint 23: x=0.55, y=1.84, z=-0.15
# Joint 24: x=0.34, y=1.78, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.15
# Joint 11: x=0.64, y=1.11, z=-0.58
# Joint 12: x=0.26, y=1.11, z=-0.43
# Joint 13: x=0.73, y=1.24, z=-0.53
# Joint 14: x=0.15, y=1.19, z=-0.21
# Joint 23: x=0.55, y=1.84, z=-0.15
# Joint 24: x=0.34, y=1.78, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.91, z=-1.11
# Joint 11: x=0.64, y=1.10, z=-0.54
# Joint 12: x=0.27, y=1.11, z=-0.39
# Joint 13: x=0.73, y=1.23, z=-0.51
# Joint 14: x=0.15, y=1.19, z=-0.18
# Joint 23: x=0.54, y=1.84, z=-0.16
# Joint 24: x=0.34, y=1.79, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.08
# Joint 11: x=0.64, y=1.10, z=-0.51
# Joint 12: x=0.26, y=1.11, z=-0.37
# Joint 13: x=0.73, y=1.24, z=-0.52
# Joint 14: x=0.14, y=1.19, z=-0.17
# Joint 23: x=0.53, y=1.84, z=-0.16
# Joint 24: x=0.33, y=1.79, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.18
# Joint 11: x=0.63, y=1.11, z=-0.58
# Joint 12: x=0.25, y=1.11, z=-0.39
# Joint 13: x=0.73, y=1.26, z=-0.74
# Joint 14: x=0.13, y=1.21, z=-0.33
# Joint 23: x=0.53, y=1.85, z=-0.16
# Joint 24: x=0.32, y=1.81, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.91, z=-1.33
# Joint 11: x=0.63, y=1.11, z=-0.71
# Joint 12: x=0.25, y=1.11, z=-0.46
# Joint 13: x=0.73, y=1.27, z=-0.82
# Joint 14: x=0.12, y=1.24, z=-0.38
# Joint 23: x=0.52, y=1.86, z=-0.16
# Joint 24: x=0.31, y=1.82, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.45
# Joint 11: x=0.63, y=1.12, z=-0.80
# Joint 12: x=0.24, y=1.12, z=-0.64
# Joint 13: x=0.75, y=1.28, z=-1.09
# Joint 14: x=0.12, y=1.24, z=-0.35
# Joint 23: x=0.53, y=1.86, z=-0.13
# Joint 24: x=0.30, y=1.82, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.43
# Joint 11: x=0.64, y=1.12, z=-0.81
# Joint 12: x=0.24, y=1.12, z=-0.65
# Joint 13: x=0.75, y=1.28, z=-0.99
# Joint 14: x=0.13, y=1.24, z=-0.34
# Joint 23: x=0.53, y=1.86, z=-0.13
# Joint 24: x=0.30, y=1.82, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.40
# Joint 11: x=0.62, y=1.14, z=-0.78
# Joint 12: x=0.24, y=1.12, z=-0.63
# Joint 13: x=0.72, y=1.27, z=-0.81
# Joint 14: x=0.13, y=1.22, z=-0.41
# Joint 23: x=0.52, y=1.87, z=-0.13
# Joint 24: x=0.30, y=1.83, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.53
# Joint 11: x=0.62, y=1.16, z=-0.86
# Joint 12: x=0.23, y=1.13, z=-0.68
# Joint 13: x=0.72, y=1.28, z=-0.88
# Joint 14: x=0.12, y=1.22, z=-0.39
# Joint 23: x=0.51, y=1.89, z=-0.13
# Joint 24: x=0.29, y=1.84, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.46
# Joint 11: x=0.61, y=1.16, z=-0.82
# Joint 12: x=0.22, y=1.14, z=-0.67
# Joint 13: x=0.71, y=1.29, z=-0.85
# Joint 14: x=0.11, y=1.24, z=-0.41
# Joint 23: x=0.51, y=1.89, z=-0.13
# Joint 24: x=0.28, y=1.85, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.53
# Joint 11: x=0.61, y=1.15, z=-0.88
# Joint 12: x=0.22, y=1.13, z=-0.66
# Joint 13: x=0.71, y=1.29, z=-0.89
# Joint 14: x=0.12, y=1.25, z=-0.34
# Joint 23: x=0.51, y=1.88, z=-0.13
# Joint 24: x=0.28, y=1.84, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.61
# Joint 11: x=0.61, y=1.15, z=-0.98
# Joint 12: x=0.23, y=1.14, z=-0.73
# Joint 13: x=0.74, y=1.31, z=-1.29
# Joint 14: x=0.11, y=1.28, z=-0.42
# Joint 23: x=0.53, y=1.88, z=-0.13
# Joint 24: x=0.28, y=1.84, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.61
# Joint 11: x=0.62, y=1.15, z=-0.98
# Joint 12: x=0.23, y=1.14, z=-0.73
# Joint 13: x=0.75, y=1.31, z=-1.30
# Joint 14: x=0.11, y=1.28, z=-0.43
# Joint 23: x=0.54, y=1.88, z=-0.13
# Joint 24: x=0.28, y=1.84, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.61
# Joint 11: x=0.62, y=1.15, z=-0.98
# Joint 12: x=0.23, y=1.14, z=-0.73
# Joint 13: x=0.75, y=1.32, z=-1.30
# Joint 14: x=0.11, y=1.28, z=-0.42
# Joint 23: x=0.54, y=1.88, z=-0.14
# Joint 24: x=0.28, y=1.84, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.56
# Joint 11: x=0.61, y=1.15, z=-0.89
# Joint 12: x=0.23, y=1.13, z=-0.60
# Joint 13: x=0.74, y=1.31, z=-0.97
# Joint 14: x=0.09, y=1.24, z=-0.40
# Joint 23: x=0.53, y=1.88, z=-0.15
# Joint 24: x=0.28, y=1.84, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.54
# Joint 11: x=0.61, y=1.15, z=-0.84
# Joint 12: x=0.23, y=1.13, z=-0.59
# Joint 13: x=0.74, y=1.28, z=-0.93
# Joint 14: x=0.10, y=1.24, z=-0.26
# Joint 23: x=0.52, y=1.87, z=-0.15
# Joint 24: x=0.28, y=1.83, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.56
# Joint 11: x=0.61, y=1.14, z=-0.87
# Joint 12: x=0.23, y=1.13, z=-0.63
# Joint 13: x=0.74, y=1.25, z=-0.94
# Joint 14: x=0.10, y=1.24, z=-0.27
# Joint 23: x=0.52, y=1.87, z=-0.15
# Joint 24: x=0.28, y=1.82, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.56
# Joint 11: x=0.61, y=1.14, z=-0.87
# Joint 12: x=0.23, y=1.13, z=-0.64
# Joint 13: x=0.74, y=1.24, z=-0.93
# Joint 14: x=0.10, y=1.24, z=-0.26
# Joint 23: x=0.52, y=1.87, z=-0.15
# Joint 24: x=0.29, y=1.82, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.50
# Joint 11: x=0.60, y=1.14, z=-0.81
# Joint 12: x=0.23, y=1.02, z=-0.59
# Joint 13: x=0.73, y=1.25, z=-0.89
# Joint 14: x=0.09, y=1.24, z=-0.20
# Joint 23: x=0.51, y=1.87, z=-0.15
# Joint 24: x=0.28, y=1.82, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.51
# Joint 11: x=0.60, y=1.14, z=-0.82
# Joint 12: x=0.23, y=1.00, z=-0.60
# Joint 13: x=0.73, y=1.25, z=-0.91
# Joint 14: x=0.09, y=1.24, z=-0.19
# Joint 23: x=0.51, y=1.87, z=-0.15
# Joint 24: x=0.28, y=1.82, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.52
# Joint 11: x=0.60, y=1.14, z=-0.85
# Joint 12: x=0.23, y=1.00, z=-0.60
# Joint 13: x=0.73, y=1.27, z=-1.05
# Joint 14: x=0.09, y=1.25, z=-0.46
# Joint 23: x=0.51, y=1.86, z=-0.15
# Joint 24: x=0.27, y=1.82, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.59
# Joint 11: x=0.60, y=1.13, z=-0.93
# Joint 12: x=0.23, y=1.00, z=-0.68
# Joint 13: x=0.73, y=1.28, z=-1.09
# Joint 14: x=0.09, y=1.26, z=-0.60
# Joint 23: x=0.51, y=1.86, z=-0.15
# Joint 24: x=0.27, y=1.82, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.70
# Joint 11: x=0.60, y=1.14, z=-1.01
# Joint 12: x=0.23, y=1.00, z=-0.82
# Joint 13: x=0.71, y=1.28, z=-1.06
# Joint 14: x=0.09, y=1.26, z=-0.61
# Joint 23: x=0.51, y=1.86, z=-0.14
# Joint 24: x=0.26, y=1.82, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.92, z=-1.69
# Joint 11: x=0.60, y=1.14, z=-0.98
# Joint 12: x=0.22, y=1.00, z=-0.76
# Joint 13: x=0.72, y=1.28, z=-1.31
# Joint 14: x=0.10, y=1.26, z=-0.58
# Joint 23: x=0.51, y=1.86, z=-0.14
# Joint 24: x=0.26, y=1.82, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.67
# Joint 11: x=0.60, y=1.14, z=-0.86
# Joint 12: x=0.22, y=1.13, z=-0.74
# Joint 13: x=0.70, y=1.24, z=-0.81
# Joint 14: x=0.10, y=1.27, z=-0.62
# Joint 23: x=0.51, y=1.88, z=-0.13
# Joint 24: x=0.28, y=1.85, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.93, z=-1.53
# Joint 11: x=0.60, y=1.14, z=-0.83
# Joint 12: x=0.22, y=1.05, z=-0.69
# Joint 13: x=0.71, y=1.24, z=-0.82
# Joint 14: x=0.10, y=1.26, z=-0.57
# Joint 23: x=0.51, y=1.88, z=-0.13
# Joint 24: x=0.28, y=1.85, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.93, z=-1.81
# Joint 11: x=0.61, y=1.19, z=-1.01
# Joint 12: x=0.22, y=1.18, z=-0.73
# Joint 13: x=0.71, y=1.28, z=-1.19
# Joint 14: x=0.10, y=1.29, z=-0.24
# Joint 23: x=0.53, y=1.95, z=-0.14
# Joint 24: x=0.28, y=1.91, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.93, z=-1.67
# Joint 11: x=0.61, y=1.19, z=-0.88
# Joint 12: x=0.21, y=1.20, z=-0.58
# Joint 13: x=0.73, y=1.31, z=-1.20
# Joint 14: x=0.10, y=1.31, z=-0.17
# Joint 23: x=0.54, y=1.95, z=-0.15
# Joint 24: x=0.28, y=1.93, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.93, z=-1.84
# Joint 11: x=0.64, y=1.19, z=-1.02
# Joint 12: x=0.22, y=1.21, z=-0.71
# Joint 13: x=0.78, y=1.32, z=-1.27
# Joint 14: x=0.10, y=1.30, z=-0.28
# Joint 23: x=0.57, y=1.98, z=-0.16
# Joint 24: x=0.30, y=1.95, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.94, z=-1.91
# Joint 11: x=0.64, y=1.20, z=-1.04
# Joint 12: x=0.22, y=1.21, z=-0.80
# Joint 13: x=0.79, y=1.31, z=-1.26
# Joint 14: x=0.10, y=1.30, z=-0.31
# Joint 23: x=0.57, y=1.99, z=-0.16
# Joint 24: x=0.31, y=1.95, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.94, z=-1.91
# Joint 11: x=0.64, y=1.19, z=-1.02
# Joint 12: x=0.22, y=1.20, z=-0.83
# Joint 13: x=0.80, y=1.31, z=-1.33
# Joint 14: x=0.09, y=1.28, z=-0.40
# Joint 23: x=0.57, y=1.98, z=-0.16
# Joint 24: x=0.30, y=1.95, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.94, z=-1.85
# Joint 11: x=0.65, y=1.19, z=-1.00
# Joint 12: x=0.22, y=1.19, z=-0.80
# Joint 13: x=0.80, y=1.31, z=-1.36
# Joint 14: x=0.09, y=1.27, z=-0.52
# Joint 23: x=0.57, y=1.97, z=-0.15
# Joint 24: x=0.30, y=1.96, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.94, z=-1.81
# Joint 11: x=0.65, y=1.19, z=-0.97
# Joint 12: x=0.22, y=1.20, z=-0.78
# Joint 13: x=0.80, y=1.31, z=-1.38
# Joint 14: x=0.09, y=1.27, z=-0.57
# Joint 23: x=0.57, y=1.97, z=-0.15
# Joint 24: x=0.30, y=1.97, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.94, z=-1.89
# Joint 11: x=0.65, y=1.19, z=-0.99
# Joint 12: x=0.22, y=1.20, z=-0.83
# Joint 13: x=0.80, y=1.31, z=-1.30
# Joint 14: x=0.09, y=1.28, z=-0.52
# Joint 23: x=0.57, y=1.98, z=-0.14
# Joint 24: x=0.30, y=1.96, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.94, z=-1.92
# Joint 11: x=0.65, y=1.19, z=-1.00
# Joint 12: x=0.22, y=1.20, z=-0.84
# Joint 13: x=0.81, y=1.31, z=-1.27
# Joint 14: x=0.09, y=1.29, z=-0.50
# Joint 23: x=0.57, y=1.98, z=-0.14
# Joint 24: x=0.30, y=1.97, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.93, z=-1.78
# Joint 11: x=0.65, y=1.19, z=-0.88
# Joint 12: x=0.22, y=1.20, z=-0.75
# Joint 13: x=0.80, y=1.31, z=-1.00
# Joint 14: x=0.09, y=1.24, z=-0.39
# Joint 23: x=0.57, y=1.98, z=-0.14
# Joint 24: x=0.31, y=1.96, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.94, z=-1.86
# Joint 11: x=0.65, y=1.19, z=-0.90
# Joint 12: x=0.22, y=1.20, z=-0.82
# Joint 13: x=0.80, y=1.30, z=-0.94
# Joint 14: x=0.09, y=1.24, z=-0.46
# Joint 23: x=0.57, y=1.99, z=-0.14
# Joint 24: x=0.31, y=1.97, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.94, z=-1.85
# Joint 11: x=0.65, y=1.19, z=-0.89
# Joint 12: x=0.22, y=1.20, z=-0.80
# Joint 13: x=0.80, y=1.30, z=-1.02
# Joint 14: x=0.09, y=1.24, z=-0.41
# Joint 23: x=0.57, y=1.99, z=-0.13
# Joint 24: x=0.31, y=1.97, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.94, z=-1.78
# Joint 11: x=0.65, y=1.19, z=-0.86
# Joint 12: x=0.23, y=1.20, z=-0.72
# Joint 13: x=0.81, y=1.30, z=-1.04
# Joint 14: x=0.09, y=1.25, z=-0.33
# Joint 23: x=0.57, y=1.99, z=-0.13
# Joint 24: x=0.31, y=1.97, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.85
# Joint 11: x=0.66, y=1.19, z=-0.89
# Joint 12: x=0.23, y=1.20, z=-0.79
# Joint 13: x=0.80, y=1.30, z=-0.97
# Joint 14: x=0.09, y=1.26, z=-0.38
# Joint 23: x=0.57, y=1.99, z=-0.13
# Joint 24: x=0.31, y=1.97, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.90
# Joint 11: x=0.66, y=1.19, z=-0.93
# Joint 12: x=0.23, y=1.20, z=-0.83
# Joint 13: x=0.80, y=1.30, z=-0.96
# Joint 14: x=0.09, y=1.27, z=-0.43
# Joint 23: x=0.57, y=1.99, z=-0.14
# Joint 24: x=0.31, y=1.97, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.89
# Joint 11: x=0.66, y=1.19, z=-0.94
# Joint 12: x=0.23, y=1.20, z=-0.85
# Joint 13: x=0.80, y=1.30, z=-1.05
# Joint 14: x=0.10, y=1.29, z=-0.57
# Joint 23: x=0.57, y=1.98, z=-0.12
# Joint 24: x=0.30, y=1.97, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.88
# Joint 11: x=0.66, y=1.18, z=-0.94
# Joint 12: x=0.22, y=1.20, z=-0.84
# Joint 13: x=0.80, y=1.30, z=-1.12
# Joint 14: x=0.10, y=1.29, z=-0.58
# Joint 23: x=0.57, y=1.97, z=-0.12
# Joint 24: x=0.30, y=1.97, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.83
# Joint 11: x=0.65, y=1.18, z=-0.92
# Joint 12: x=0.22, y=1.20, z=-0.81
# Joint 13: x=0.80, y=1.31, z=-1.26
# Joint 14: x=0.10, y=1.29, z=-0.54
# Joint 23: x=0.57, y=1.97, z=-0.12
# Joint 24: x=0.30, y=1.97, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.80
# Joint 11: x=0.65, y=1.18, z=-0.91
# Joint 12: x=0.21, y=1.20, z=-0.78
# Joint 13: x=0.80, y=1.31, z=-1.26
# Joint 14: x=0.10, y=1.29, z=-0.53
# Joint 23: x=0.57, y=1.97, z=-0.12
# Joint 24: x=0.30, y=1.97, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.81
# Joint 11: x=0.65, y=1.19, z=-0.91
# Joint 12: x=0.21, y=1.20, z=-0.76
# Joint 13: x=0.80, y=1.33, z=-1.28
# Joint 14: x=0.09, y=1.31, z=-0.44
# Joint 23: x=0.56, y=1.99, z=-0.13
# Joint 24: x=0.29, y=1.98, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.96
# Joint 11: x=0.65, y=1.19, z=-0.97
# Joint 12: x=0.21, y=1.20, z=-0.87
# Joint 13: x=0.80, y=1.31, z=-1.24
# Joint 14: x=0.08, y=1.31, z=-0.51
# Joint 23: x=0.56, y=1.99, z=-0.13
# Joint 24: x=0.29, y=1.98, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.63
# Joint 11: x=0.65, y=1.19, z=-0.78
# Joint 12: x=0.22, y=1.20, z=-0.58
# Joint 13: x=0.79, y=1.32, z=-1.05
# Joint 14: x=0.08, y=1.29, z=-0.32
# Joint 23: x=0.56, y=1.99, z=-0.15
# Joint 24: x=0.30, y=1.98, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.57
# Joint 11: x=0.65, y=1.19, z=-0.74
# Joint 12: x=0.22, y=1.20, z=-0.53
# Joint 13: x=0.79, y=1.32, z=-1.02
# Joint 14: x=0.08, y=1.28, z=-0.30
# Joint 23: x=0.56, y=1.99, z=-0.16
# Joint 24: x=0.30, y=1.98, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.55
# Joint 11: x=0.65, y=1.19, z=-0.72
# Joint 12: x=0.22, y=1.20, z=-0.51
# Joint 13: x=0.79, y=1.32, z=-1.03
# Joint 14: x=0.08, y=1.28, z=-0.32
# Joint 23: x=0.56, y=1.99, z=-0.16
# Joint 24: x=0.30, y=1.98, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.83
# Joint 11: x=0.66, y=1.20, z=-0.96
# Joint 12: x=0.23, y=1.21, z=-0.77
# Joint 13: x=0.80, y=1.33, z=-1.30
# Joint 14: x=0.10, y=1.28, z=-0.56
# Joint 23: x=0.57, y=2.01, z=-0.16
# Joint 24: x=0.30, y=1.99, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.91
# Joint 11: x=0.66, y=1.20, z=-0.96
# Joint 12: x=0.22, y=1.21, z=-0.82
# Joint 13: x=0.80, y=1.32, z=-1.23
# Joint 14: x=0.08, y=1.28, z=-0.50
# Joint 23: x=0.57, y=2.01, z=-0.15
# Joint 24: x=0.30, y=1.99, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.86
# Joint 11: x=0.66, y=1.20, z=-0.94
# Joint 12: x=0.22, y=1.21, z=-0.79
# Joint 13: x=0.80, y=1.31, z=-1.20
# Joint 14: x=0.07, y=1.28, z=-0.45
# Joint 23: x=0.57, y=2.01, z=-0.14
# Joint 24: x=0.30, y=2.00, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.84
# Joint 11: x=0.65, y=1.20, z=-0.93
# Joint 12: x=0.22, y=1.21, z=-0.78
# Joint 13: x=0.80, y=1.30, z=-1.20
# Joint 14: x=0.07, y=1.28, z=-0.44
# Joint 23: x=0.57, y=2.01, z=-0.14
# Joint 24: x=0.30, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.73
# Joint 11: x=0.66, y=1.20, z=-0.86
# Joint 12: x=0.22, y=1.21, z=-0.69
# Joint 13: x=0.80, y=1.30, z=-1.19
# Joint 14: x=0.09, y=1.28, z=-0.41
# Joint 23: x=0.57, y=2.01, z=-0.14
# Joint 24: x=0.31, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.73
# Joint 11: x=0.66, y=1.20, z=-0.85
# Joint 12: x=0.22, y=1.21, z=-0.69
# Joint 13: x=0.80, y=1.30, z=-1.17
# Joint 14: x=0.09, y=1.28, z=-0.40
# Joint 23: x=0.57, y=2.02, z=-0.14
# Joint 24: x=0.31, y=2.00, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.80
# Joint 11: x=0.66, y=1.20, z=-0.94
# Joint 12: x=0.22, y=1.21, z=-0.77
# Joint 13: x=0.80, y=1.30, z=-1.07
# Joint 14: x=0.10, y=1.28, z=-0.44
# Joint 23: x=0.57, y=2.02, z=-0.14
# Joint 24: x=0.31, y=2.00, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.77
# Joint 11: x=0.65, y=1.20, z=-0.89
# Joint 12: x=0.22, y=1.21, z=-0.76
# Joint 13: x=0.80, y=1.30, z=-1.03
# Joint 14: x=0.10, y=1.30, z=-0.47
# Joint 23: x=0.57, y=2.02, z=-0.13
# Joint 24: x=0.30, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.76
# Joint 11: x=0.65, y=1.20, z=-0.89
# Joint 12: x=0.22, y=1.21, z=-0.76
# Joint 13: x=0.80, y=1.30, z=-1.06
# Joint 14: x=0.10, y=1.31, z=-0.47
# Joint 23: x=0.57, y=2.02, z=-0.13
# Joint 24: x=0.29, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.76
# Joint 11: x=0.65, y=1.20, z=-0.89
# Joint 12: x=0.21, y=1.21, z=-0.75
# Joint 13: x=0.80, y=1.30, z=-1.14
# Joint 14: x=0.10, y=1.31, z=-0.49
# Joint 23: x=0.56, y=2.02, z=-0.13
# Joint 24: x=0.29, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.97
# Joint 11: x=0.65, y=1.20, z=-0.99
# Joint 12: x=0.21, y=1.21, z=-0.86
# Joint 13: x=0.81, y=1.31, z=-1.30
# Joint 14: x=0.09, y=1.29, z=-0.51
# Joint 23: x=0.55, y=2.02, z=-0.14
# Joint 24: x=0.29, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-2.00
# Joint 11: x=0.65, y=1.21, z=-1.01
# Joint 12: x=0.21, y=1.20, z=-0.88
# Joint 13: x=0.81, y=1.31, z=-1.33
# Joint 14: x=0.08, y=1.28, z=-0.51
# Joint 23: x=0.55, y=2.02, z=-0.14
# Joint 24: x=0.29, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-2.01
# Joint 11: x=0.65, y=1.21, z=-1.03
# Joint 12: x=0.21, y=1.20, z=-0.90
# Joint 13: x=0.82, y=1.31, z=-1.32
# Joint 14: x=0.08, y=1.28, z=-0.51
# Joint 23: x=0.55, y=2.02, z=-0.14
# Joint 24: x=0.29, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.82
# Joint 11: x=0.67, y=1.19, z=-0.87
# Joint 12: x=0.22, y=1.21, z=-0.75
# Joint 13: x=0.82, y=1.29, z=-0.91
# Joint 14: x=0.10, y=1.29, z=-0.41
# Joint 23: x=0.59, y=2.02, z=-0.14
# Joint 24: x=0.32, y=2.01, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.70
# Joint 11: x=0.67, y=1.19, z=-0.80
# Joint 12: x=0.23, y=1.21, z=-0.71
# Joint 13: x=0.82, y=1.29, z=-0.86
# Joint 14: x=0.11, y=1.27, z=-0.39
# Joint 23: x=0.59, y=2.02, z=-0.14
# Joint 24: x=0.32, y=2.01, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.72
# Joint 11: x=0.66, y=1.19, z=-0.82
# Joint 12: x=0.23, y=1.21, z=-0.73
# Joint 13: x=0.82, y=1.29, z=-0.94
# Joint 14: x=0.12, y=1.26, z=-0.40
# Joint 23: x=0.59, y=2.02, z=-0.14
# Joint 24: x=0.32, y=2.01, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.59
# Joint 11: x=0.67, y=1.19, z=-0.71
# Joint 12: x=0.23, y=1.22, z=-0.62
# Joint 13: x=0.81, y=1.29, z=-0.80
# Joint 14: x=0.13, y=1.28, z=-0.48
# Joint 23: x=0.60, y=2.02, z=-0.13
# Joint 24: x=0.33, y=2.01, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.81
# Joint 11: x=0.67, y=1.18, z=-0.91
# Joint 12: x=0.23, y=1.22, z=-0.85
# Joint 13: x=0.81, y=1.29, z=-1.11
# Joint 14: x=0.14, y=1.28, z=-0.82
# Joint 23: x=0.60, y=2.02, z=-0.14
# Joint 24: x=0.33, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.84
# Joint 11: x=0.67, y=1.18, z=-0.93
# Joint 12: x=0.23, y=1.22, z=-0.85
# Joint 13: x=0.81, y=1.29, z=-1.11
# Joint 14: x=0.14, y=1.28, z=-0.77
# Joint 23: x=0.60, y=2.02, z=-0.14
# Joint 24: x=0.34, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.83
# Joint 11: x=0.67, y=1.18, z=-0.93
# Joint 12: x=0.23, y=1.21, z=-0.78
# Joint 13: x=0.81, y=1.32, z=-1.36
# Joint 14: x=0.13, y=1.29, z=-0.71
# Joint 23: x=0.60, y=2.02, z=-0.14
# Joint 24: x=0.33, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.83
# Joint 11: x=0.67, y=1.18, z=-0.92
# Joint 12: x=0.23, y=1.21, z=-0.74
# Joint 13: x=0.81, y=1.34, z=-1.35
# Joint 14: x=0.12, y=1.30, z=-0.59
# Joint 23: x=0.60, y=2.02, z=-0.14
# Joint 24: x=0.33, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-2.00
# Joint 11: x=0.67, y=1.20, z=-1.04
# Joint 12: x=0.23, y=1.22, z=-0.91
# Joint 13: x=0.81, y=1.33, z=-1.26
# Joint 14: x=0.10, y=1.29, z=-0.69
# Joint 23: x=0.60, y=2.05, z=-0.16
# Joint 24: x=0.33, y=2.02, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.94
# Joint 11: x=0.67, y=1.20, z=-1.02
# Joint 12: x=0.22, y=1.22, z=-0.88
# Joint 13: x=0.82, y=1.33, z=-1.29
# Joint 14: x=0.10, y=1.29, z=-0.66
# Joint 23: x=0.60, y=2.04, z=-0.14
# Joint 24: x=0.32, y=2.02, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.91
# Joint 11: x=0.67, y=1.20, z=-1.00
# Joint 12: x=0.22, y=1.22, z=-0.86
# Joint 13: x=0.82, y=1.33, z=-1.29
# Joint 14: x=0.09, y=1.29, z=-0.65
# Joint 23: x=0.60, y=2.04, z=-0.14
# Joint 24: x=0.31, y=2.02, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.91
# Joint 11: x=0.67, y=1.20, z=-0.98
# Joint 12: x=0.22, y=1.21, z=-0.85
# Joint 13: x=0.82, y=1.33, z=-1.28
# Joint 14: x=0.09, y=1.30, z=-0.64
# Joint 23: x=0.60, y=2.04, z=-0.13
# Joint 24: x=0.31, y=2.02, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.75
# Joint 11: x=0.67, y=1.21, z=-0.85
# Joint 12: x=0.22, y=1.23, z=-0.73
# Joint 13: x=0.81, y=1.34, z=-1.06
# Joint 14: x=0.09, y=1.31, z=-0.64
# Joint 23: x=0.59, y=2.04, z=-0.13
# Joint 24: x=0.31, y=2.04, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.74
# Joint 11: x=0.67, y=1.21, z=-0.84
# Joint 12: x=0.22, y=1.24, z=-0.73
# Joint 13: x=0.81, y=1.33, z=-1.03
# Joint 14: x=0.10, y=1.31, z=-0.64
# Joint 23: x=0.59, y=2.05, z=-0.13
# Joint 24: x=0.31, y=2.04, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.73
# Joint 11: x=0.67, y=1.21, z=-0.83
# Joint 12: x=0.22, y=1.24, z=-0.71
# Joint 13: x=0.81, y=1.33, z=-1.04
# Joint 14: x=0.10, y=1.32, z=-0.64
# Joint 23: x=0.60, y=2.05, z=-0.13
# Joint 24: x=0.31, y=2.05, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.93
# Joint 11: x=0.67, y=1.21, z=-0.96
# Joint 12: x=0.22, y=1.24, z=-0.81
# Joint 13: x=0.80, y=1.33, z=-1.03
# Joint 14: x=0.08, y=1.31, z=-0.41
# Joint 23: x=0.58, y=2.05, z=-0.15
# Joint 24: x=0.31, y=2.05, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.93
# Joint 11: x=0.66, y=1.20, z=-0.92
# Joint 12: x=0.22, y=1.21, z=-0.81
# Joint 13: x=0.80, y=1.29, z=-0.89
# Joint 14: x=0.08, y=1.27, z=-0.44
# Joint 23: x=0.58, y=2.02, z=-0.15
# Joint 24: x=0.31, y=2.02, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.94, z=-1.88
# Joint 11: x=0.66, y=1.19, z=-0.87
# Joint 12: x=0.22, y=1.21, z=-0.80
# Joint 13: x=0.80, y=1.27, z=-0.82
# Joint 14: x=0.08, y=1.26, z=-0.46
# Joint 23: x=0.58, y=2.02, z=-0.14
# Joint 24: x=0.31, y=2.02, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.87
# Joint 11: x=0.65, y=1.19, z=-0.89
# Joint 12: x=0.21, y=1.20, z=-0.85
# Joint 13: x=0.79, y=1.27, z=-1.27
# Joint 14: x=0.09, y=1.26, z=-0.70
# Joint 23: x=0.57, y=2.02, z=-0.13
# Joint 24: x=0.30, y=2.01, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.97
# Joint 11: x=0.65, y=1.19, z=-0.99
# Joint 12: x=0.21, y=1.20, z=-0.96
# Joint 13: x=0.79, y=1.27, z=-1.26
# Joint 14: x=0.09, y=1.26, z=-0.73
# Joint 23: x=0.55, y=2.01, z=-0.12
# Joint 24: x=0.29, y=2.00, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.95
# Joint 11: x=0.64, y=1.18, z=-0.91
# Joint 12: x=0.21, y=1.19, z=-0.94
# Joint 13: x=0.79, y=1.22, z=-0.79
# Joint 14: x=0.11, y=1.23, z=-0.71
# Joint 23: x=0.55, y=1.99, z=-0.12
# Joint 24: x=0.30, y=1.97, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.84
# Joint 11: x=0.64, y=1.17, z=-0.88
# Joint 12: x=0.22, y=1.19, z=-0.94
# Joint 13: x=0.77, y=1.23, z=-0.93
# Joint 14: x=0.17, y=1.24, z=-1.10
# Joint 23: x=0.56, y=1.98, z=-0.12
# Joint 24: x=0.31, y=1.96, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.82
# Joint 11: x=0.64, y=1.17, z=-0.89
# Joint 12: x=0.22, y=1.19, z=-0.94
# Joint 13: x=0.77, y=1.23, z=-1.14
# Joint 14: x=0.17, y=1.24, z=-1.26
# Joint 23: x=0.55, y=1.99, z=-0.12
# Joint 24: x=0.31, y=1.96, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.50
# Joint 11: x=0.63, y=1.16, z=-0.69
# Joint 12: x=0.22, y=1.18, z=-0.74
# Joint 13: x=0.76, y=1.24, z=-0.70
# Joint 14: x=0.16, y=1.24, z=-1.01
# Joint 23: x=0.55, y=1.97, z=-0.12
# Joint 24: x=0.31, y=1.95, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.65
# Joint 11: x=0.63, y=1.15, z=-0.72
# Joint 12: x=0.22, y=1.18, z=-0.82
# Joint 13: x=0.76, y=1.23, z=-0.79
# Joint 14: x=0.15, y=1.26, z=-0.94
# Joint 23: x=0.55, y=1.96, z=-0.11
# Joint 24: x=0.31, y=1.95, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.69
# Joint 11: x=0.63, y=1.15, z=-0.78
# Joint 12: x=0.22, y=1.18, z=-0.83
# Joint 13: x=0.76, y=1.24, z=-0.85
# Joint 14: x=0.15, y=1.25, z=-0.93
# Joint 23: x=0.55, y=1.96, z=-0.11
# Joint 24: x=0.31, y=1.95, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.71
# Joint 11: x=0.63, y=1.15, z=-0.77
# Joint 12: x=0.22, y=1.17, z=-0.83
# Joint 13: x=0.75, y=1.24, z=-0.83
# Joint 14: x=0.15, y=1.23, z=-0.74
# Joint 23: x=0.54, y=1.96, z=-0.11
# Joint 24: x=0.31, y=1.94, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.72
# Joint 11: x=0.63, y=1.15, z=-0.79
# Joint 12: x=0.22, y=1.17, z=-0.84
# Joint 13: x=0.75, y=1.24, z=-1.13
# Joint 14: x=0.17, y=1.23, z=-1.06
# Joint 23: x=0.54, y=1.96, z=-0.11
# Joint 24: x=0.31, y=1.94, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.71
# Joint 11: x=0.63, y=1.15, z=-0.80
# Joint 12: x=0.22, y=1.17, z=-0.84
# Joint 13: x=0.76, y=1.24, z=-1.12
# Joint 14: x=0.17, y=1.23, z=-1.06
# Joint 23: x=0.54, y=1.96, z=-0.11
# Joint 24: x=0.31, y=1.94, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.45, y=0.94, z=-1.30
# Joint 11: x=0.63, y=1.13, z=-0.54
# Joint 12: x=0.23, y=1.16, z=-0.45
# Joint 13: x=0.75, y=1.24, z=-0.78
# Joint 14: x=0.17, y=1.23, z=-0.69
# Joint 23: x=0.55, y=1.94, z=-0.14
# Joint 24: x=0.32, y=1.93, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.36
# Joint 11: x=0.64, y=1.13, z=-0.62
# Joint 12: x=0.24, y=1.16, z=-0.47
# Joint 13: x=0.75, y=1.28, z=-1.12
# Joint 14: x=0.18, y=1.26, z=-0.80
# Joint 23: x=0.57, y=1.93, z=-0.16
# Joint 24: x=0.33, y=1.92, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.93, z=-1.35
# Joint 11: x=0.63, y=1.05, z=-0.61
# Joint 12: x=0.24, y=1.15, z=-0.49
# Joint 13: x=0.75, y=1.28, z=-1.05
# Joint 14: x=0.17, y=1.26, z=-0.81
# Joint 23: x=0.57, y=1.91, z=-0.16
# Joint 24: x=0.34, y=1.90, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.17
# Joint 11: x=0.62, y=1.07, z=-0.48
# Joint 12: x=0.25, y=1.05, z=-0.41
# Joint 13: x=0.73, y=1.27, z=-0.80
# Joint 14: x=0.21, y=1.26, z=-0.77
# Joint 23: x=0.56, y=1.90, z=-0.16
# Joint 24: x=0.33, y=1.89, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.28
# Joint 11: x=0.62, y=1.08, z=-0.57
# Joint 12: x=0.25, y=1.03, z=-0.52
# Joint 13: x=0.74, y=1.27, z=-0.83
# Joint 14: x=0.23, y=1.26, z=-0.79
# Joint 23: x=0.56, y=1.89, z=-0.16
# Joint 24: x=0.33, y=1.88, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.28
# Joint 11: x=0.62, y=1.09, z=-0.59
# Joint 12: x=0.25, y=1.03, z=-0.51
# Joint 13: x=0.74, y=1.27, z=-0.87
# Joint 14: x=0.23, y=1.26, z=-0.79
# Joint 23: x=0.56, y=1.88, z=-0.16
# Joint 24: x=0.33, y=1.87, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.28
# Joint 11: x=0.62, y=1.09, z=-0.60
# Joint 12: x=0.25, y=1.02, z=-0.53
# Joint 13: x=0.74, y=1.26, z=-0.88
# Joint 14: x=0.23, y=1.25, z=-0.77
# Joint 23: x=0.56, y=1.85, z=-0.16
# Joint 24: x=0.33, y=1.84, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.33
# Joint 11: x=0.62, y=1.09, z=-0.61
# Joint 12: x=0.25, y=1.01, z=-0.66
# Joint 13: x=0.74, y=1.24, z=-0.87
# Joint 14: x=0.24, y=1.25, z=-0.93
# Joint 23: x=0.56, y=1.86, z=-0.14
# Joint 24: x=0.33, y=1.85, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.35
# Joint 11: x=0.62, y=1.09, z=-0.62
# Joint 12: x=0.25, y=1.01, z=-0.64
# Joint 13: x=0.74, y=1.24, z=-0.91
# Joint 14: x=0.22, y=1.25, z=-0.88
# Joint 23: x=0.56, y=1.86, z=-0.14
# Joint 24: x=0.33, y=1.85, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.46
# Joint 11: x=0.63, y=1.10, z=-0.78
# Joint 12: x=0.25, y=1.00, z=-0.64
# Joint 13: x=0.74, y=1.24, z=-0.91
# Joint 14: x=0.17, y=1.25, z=-0.75
# Joint 23: x=0.56, y=1.86, z=-0.15
# Joint 24: x=0.33, y=1.84, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.66
# Joint 11: x=0.64, y=1.11, z=-0.93
# Joint 12: x=0.25, y=1.01, z=-0.70
# Joint 13: x=0.75, y=1.24, z=-1.19
# Joint 14: x=0.14, y=1.25, z=-0.75
# Joint 23: x=0.56, y=1.87, z=-0.16
# Joint 24: x=0.33, y=1.84, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.69
# Joint 11: x=0.64, y=1.13, z=-0.96
# Joint 12: x=0.25, y=1.02, z=-0.71
# Joint 13: x=0.75, y=1.26, z=-1.25
# Joint 14: x=0.13, y=1.25, z=-0.73
# Joint 23: x=0.57, y=1.88, z=-0.16
# Joint 24: x=0.33, y=1.85, z=0.17
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.70
# Joint 11: x=0.65, y=1.14, z=-0.98
# Joint 12: x=0.25, y=1.02, z=-0.77
# Joint 13: x=0.77, y=1.27, z=-1.24
# Joint 14: x=0.13, y=1.26, z=-0.59
# Joint 23: x=0.57, y=1.89, z=-0.16
# Joint 24: x=0.34, y=1.85, z=0.16
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.66
# Joint 11: x=0.64, y=1.04, z=-0.90
# Joint 12: x=0.25, y=1.12, z=-0.74
# Joint 13: x=0.77, y=1.27, z=-1.16
# Joint 14: x=0.14, y=1.26, z=-0.63
# Joint 23: x=0.57, y=1.88, z=-0.15
# Joint 24: x=0.34, y=1.85, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.64
# Joint 11: x=0.64, y=1.02, z=-0.88
# Joint 12: x=0.25, y=1.14, z=-0.73
# Joint 13: x=0.76, y=1.27, z=-1.15
# Joint 14: x=0.14, y=1.27, z=-0.67
# Joint 23: x=0.58, y=1.87, z=-0.14
# Joint 24: x=0.34, y=1.85, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.71
# Joint 11: x=0.64, y=1.00, z=-0.92
# Joint 12: x=0.25, y=1.05, z=-0.81
# Joint 13: x=0.77, y=1.27, z=-1.26
# Joint 14: x=0.13, y=1.23, z=-0.85
# Joint 23: x=0.57, y=1.86, z=-0.14
# Joint 24: x=0.34, y=1.83, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.66
# Joint 11: x=0.63, y=1.01, z=-0.89
# Joint 12: x=0.25, y=1.03, z=-0.77
# Joint 13: x=0.77, y=1.27, z=-1.21
# Joint 14: x=0.14, y=1.23, z=-0.82
# Joint 23: x=0.57, y=1.86, z=-0.14
# Joint 24: x=0.34, y=1.83, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.44, y=0.92, z=-1.65
# Joint 11: x=0.63, y=1.01, z=-0.88
# Joint 12: x=0.25, y=1.02, z=-0.76
# ...
# Joint 24: x=0.26, y=1.94, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.50, y=0.68, z=-1.15
# Joint 11: x=0.66, y=1.00, z=-0.24
# Joint 12: x=0.19, y=0.99, z=-0.19
# Joint 13: x=0.82, y=1.21, z=-0.55
# Joint 14: x=0.02, y=1.38, z=-0.59
# Joint 23: x=0.60, y=1.99, z=-0.14
# Joint 24: x=0.26, y=1.98, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.51, y=0.68, z=-1.09
# Joint 11: x=0.66, y=1.00, z=-0.21
# Joint 12: x=0.19, y=0.98, z=-0.17
# Joint 13: x=0.83, y=1.24, z=-0.57
# Joint 14: x=0.02, y=1.38, z=-0.58
# Joint 23: x=0.60, y=1.98, z=-0.14
# Joint 24: x=0.26, y=1.98, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.51, y=0.68, z=-1.15
# Joint 11: x=0.67, y=1.00, z=-0.23
# Joint 12: x=0.19, y=0.98, z=-0.19
# Joint 13: x=0.83, y=1.25, z=-0.51
# Joint 14: x=0.01, y=1.36, z=-0.54
# Joint 23: x=0.60, y=1.98, z=-0.14
# Joint 24: x=0.26, y=1.98, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.52, y=0.69, z=-1.17
# Joint 11: x=0.66, y=0.99, z=-0.23
# Joint 12: x=0.18, y=0.97, z=-0.19
# Joint 13: x=0.82, y=1.22, z=-0.49
# Joint 14: x=0.00, y=1.28, z=-0.62
# Joint 23: x=0.60, y=1.97, z=-0.15
# Joint 24: x=0.25, y=1.97, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.52, y=0.69, z=-1.22
# Joint 11: x=0.67, y=0.99, z=-0.21
# Joint 12: x=0.18, y=0.97, z=-0.28
# Joint 13: x=0.83, y=1.21, z=-0.39
# Joint 14: x=0.01, y=1.30, z=-0.59
# Joint 23: x=0.60, y=1.97, z=-0.12
# Joint 24: x=0.26, y=1.97, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.52, y=0.69, z=-1.24
# Joint 11: x=0.67, y=0.99, z=-0.20
# Joint 12: x=0.18, y=0.98, z=-0.30
# Joint 13: x=0.83, y=1.21, z=-0.39
# Joint 14: x=0.02, y=1.32, z=-0.60
# Joint 23: x=0.60, y=1.97, z=-0.11
# Joint 24: x=0.26, y=1.97, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.52, y=0.69, z=-1.41
# Joint 11: x=0.67, y=0.99, z=-0.38
# Joint 12: x=0.18, y=0.98, z=-0.35
# Joint 13: x=0.83, y=1.11, z=-0.41
# Joint 14: x=0.00, y=1.27, z=-0.52
# Joint 23: x=0.60, y=1.97, z=-0.13
# Joint 24: x=0.26, y=1.97, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.52, y=0.69, z=-1.44
# Joint 11: x=0.67, y=0.99, z=-0.41
# Joint 12: x=0.18, y=0.98, z=-0.36
# Joint 13: x=0.83, y=1.08, z=-0.42
# Joint 14: x=-0.01, y=1.26, z=-0.49
# Joint 23: x=0.60, y=1.97, z=-0.14
# Joint 24: x=0.26, y=1.97, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.51, y=0.69, z=-1.21
# Joint 11: x=0.67, y=0.97, z=-0.24
# Joint 12: x=0.18, y=0.98, z=-0.36
# Joint 13: x=0.90, y=0.72, z=-0.47
# Joint 14: x=0.01, y=1.27, z=-0.71
# Joint 23: x=0.61, y=1.96, z=-0.09
# Joint 24: x=0.28, y=1.96, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.51, y=0.69, z=-1.22
# Joint 11: x=0.67, y=0.97, z=-0.23
# Joint 12: x=0.18, y=0.98, z=-0.35
# Joint 13: x=0.90, y=0.76, z=-0.47
# Joint 14: x=0.02, y=1.29, z=-0.74
# Joint 23: x=0.61, y=1.96, z=-0.08
# Joint 24: x=0.28, y=1.96, z=0.08
# Data sent to Unity 🚀
# Joint 0: x=0.51, y=0.69, z=-1.36
# Joint 11: x=0.68, y=0.97, z=-0.28
# Joint 12: x=0.18, y=0.98, z=-0.44
# Joint 13: x=0.92, y=0.68, z=-0.55
# Joint 14: x=0.02, y=1.30, z=-0.69
# Joint 23: x=0.61, y=1.97, z=-0.08
# Joint 24: x=0.28, y=1.96, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.51, y=0.69, z=-1.39
# Joint 11: x=0.68, y=0.97, z=-0.31
# Joint 12: x=0.18, y=0.99, z=-0.46
# Joint 13: x=0.92, y=0.68, z=-0.58
# Joint 14: x=0.02, y=1.30, z=-0.69
# Joint 23: x=0.61, y=1.97, z=-0.08
# Joint 24: x=0.28, y=1.96, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.50, y=0.69, z=-1.27
# Joint 11: x=0.69, y=0.94, z=-0.33
# Joint 12: x=0.18, y=0.98, z=-0.24
# Joint 13: x=0.97, y=0.53, z=-0.82
# Joint 14: x=-0.07, y=1.07, z=-0.65
# Joint 23: x=0.64, y=1.92, z=-0.08
# Joint 24: x=0.29, y=1.93, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.49, y=0.68, z=-1.27
# Joint 11: x=0.70, y=0.94, z=-0.35
# Joint 12: x=0.18, y=0.99, z=-0.23
# Joint 13: x=0.99, y=0.50, z=-0.86
# Joint 14: x=-0.04, y=1.19, z=-0.53
# Joint 23: x=0.65, y=1.93, z=-0.09
# Joint 24: x=0.30, y=1.94, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.49, y=0.68, z=-1.30
# Joint 11: x=0.71, y=0.94, z=-0.37
# Joint 12: x=0.18, y=0.99, z=-0.26
# Joint 13: x=1.00, y=0.51, z=-0.90
# Joint 14: x=-0.02, y=1.29, z=-0.44
# Joint 23: x=0.65, y=1.93, z=-0.09
# Joint 24: x=0.30, y=1.94, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.48, y=0.68, z=-1.32
# Joint 11: x=0.71, y=0.94, z=-0.42
# Joint 12: x=0.18, y=0.99, z=-0.22
# Joint 13: x=1.00, y=0.51, z=-0.94
# Joint 14: x=-0.03, y=1.19, z=-0.47
# Joint 23: x=0.65, y=1.93, z=-0.11
# Joint 24: x=0.30, y=1.94, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.48, y=0.68, z=-1.17
# Joint 11: x=0.71, y=0.94, z=-0.28
# Joint 12: x=0.18, y=1.00, z=-0.21
# Joint 13: x=1.00, y=0.53, z=-0.88
# Joint 14: x=-0.03, y=1.21, z=-0.48
# Joint 23: x=0.65, y=1.93, z=-0.07
# Joint 24: x=0.30, y=1.94, z=0.08
# Data sent to Unity 🚀
# Joint 0: x=0.48, y=0.68, z=-1.15
# Joint 11: x=0.71, y=0.93, z=-0.23
# Joint 12: x=0.18, y=1.00, z=-0.22
# Joint 13: x=1.00, y=0.52, z=-0.75
# Joint 14: x=-0.02, y=1.23, z=-0.50
# Joint 23: x=0.66, y=1.93, z=-0.05
# Joint 24: x=0.31, y=1.94, z=0.06
# Data sent to Unity 🚀
# Joint 0: x=0.48, y=0.68, z=-1.43
# Joint 11: x=0.71, y=0.93, z=-0.49
# Joint 12: x=0.19, y=1.00, z=-0.39
# Joint 13: x=1.01, y=0.54, z=-1.01
# Joint 14: x=-0.01, y=1.24, z=-0.63
# Joint 23: x=0.66, y=1.93, z=-0.07
# Joint 24: x=0.32, y=1.94, z=0.08
# Data sent to Unity 🚀
# Joint 0: x=0.48, y=0.68, z=-1.40
# Joint 11: x=0.71, y=0.93, z=-0.48
# Joint 12: x=0.19, y=1.00, z=-0.36
# Joint 13: x=1.01, y=0.54, z=-0.99
# Joint 14: x=-0.02, y=1.24, z=-0.61
# Joint 23: x=0.66, y=1.93, z=-0.08
# Joint 24: x=0.32, y=1.94, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.48, y=0.68, z=-1.45
# Joint 11: x=0.71, y=0.93, z=-0.51
# Joint 12: x=0.19, y=1.00, z=-0.40
# Joint 13: x=1.02, y=0.54, z=-1.01
# Joint 14: x=-0.02, y=1.31, z=-0.41
# Joint 23: x=0.66, y=1.93, z=-0.09
# Joint 24: x=0.32, y=1.94, z=0.10
# Data sent to Unity 🚀
# Joint 0: x=0.48, y=0.68, z=-1.73
# Joint 11: x=0.71, y=0.93, z=-0.71
# Joint 12: x=0.19, y=1.01, z=-0.70
# Joint 13: x=1.02, y=0.55, z=-1.17
# Joint 14: x=-0.01, y=1.43, z=-0.48
# Joint 23: x=0.66, y=1.93, z=-0.10
# Joint 24: x=0.32, y=1.94, z=0.10
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.67, z=-1.55
# Joint 11: x=0.71, y=0.93, z=-0.59
# Joint 12: x=0.19, y=1.01, z=-0.55
# Joint 13: x=1.02, y=0.54, z=-1.04
# Joint 14: x=0.03, y=1.41, z=-0.34
# Joint 23: x=0.66, y=1.93, z=-0.09
# Joint 24: x=0.31, y=1.94, z=0.10
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.67, z=-1.48
# Joint 11: x=0.71, y=0.93, z=-0.56
# Joint 12: x=0.19, y=1.01, z=-0.45
# Joint 13: x=1.02, y=0.54, z=-1.02
# Joint 14: x=0.05, y=1.43, z=-0.24
# Joint 23: x=0.66, y=1.94, z=-0.10
# Joint 24: x=0.31, y=1.96, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.46, y=0.67, z=-1.45
# Joint 11: x=0.71, y=0.93, z=-0.56
# Joint 12: x=0.19, y=1.01, z=-0.42
# Joint 13: x=1.03, y=0.54, z=-1.01
# Joint 14: x=0.06, y=1.43, z=-0.25
# Joint 23: x=0.66, y=1.95, z=-0.10
# Joint 24: x=0.31, y=1.96, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.46, y=0.67, z=-1.58
# Joint 11: x=0.71, y=0.92, z=-0.60
# Joint 12: x=0.18, y=1.01, z=-0.44
# Joint 13: x=1.02, y=0.54, z=-1.12
# Joint 14: x=0.03, y=1.40, z=-0.43
# Joint 23: x=0.66, y=1.95, z=-0.12
# Joint 24: x=0.31, y=1.96, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.46, y=0.67, z=-1.54
# Joint 11: x=0.71, y=0.93, z=-0.56
# Joint 12: x=0.18, y=1.01, z=-0.43
# Joint 13: x=1.02, y=0.54, z=-1.07
# Joint 14: x=0.03, y=1.49, z=-0.27
# Joint 23: x=0.66, y=1.96, z=-0.12
# Joint 24: x=0.31, y=1.98, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.46, y=0.67, z=-1.51
# Joint 11: x=0.71, y=0.92, z=-0.55
# Joint 12: x=0.18, y=1.01, z=-0.43
# Joint 13: x=1.02, y=0.54, z=-1.06
# Joint 14: x=0.04, y=1.51, z=-0.21
# Joint 23: x=0.66, y=1.97, z=-0.12
# Joint 24: x=0.31, y=1.98, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.66, z=-1.50
# Joint 11: x=0.71, y=0.92, z=-0.55
# Joint 12: x=0.18, y=1.01, z=-0.43
# Joint 13: x=1.02, y=0.54, z=-1.07
# Joint 14: x=0.05, y=1.51, z=-0.18
# Joint 23: x=0.66, y=1.97, z=-0.12
# Joint 24: x=0.31, y=1.98, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.66, z=-1.64
# Joint 11: x=0.71, y=0.92, z=-0.66
# Joint 12: x=0.18, y=1.01, z=-0.52
# Joint 13: x=1.02, y=0.54, z=-1.20
# Joint 14: x=-0.01, y=1.32, z=-0.63
# Joint 23: x=0.66, y=1.97, z=-0.13
# Joint 24: x=0.31, y=1.98, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.66, z=-1.64
# Joint 11: x=0.71, y=0.92, z=-0.66
# Joint 12: x=0.18, y=1.01, z=-0.53
# Joint 13: x=1.02, y=0.55, z=-1.19
# Joint 14: x=-0.02, y=1.29, z=-0.66
# Joint 23: x=0.66, y=1.97, z=-0.13
# Joint 24: x=0.31, y=1.98, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.66, z=-1.60
# Joint 11: x=0.71, y=0.92, z=-0.64
# Joint 12: x=0.18, y=1.01, z=-0.52
# Joint 13: x=1.02, y=0.55, z=-1.17
# Joint 14: x=0.02, y=1.44, z=-0.46
# Joint 23: x=0.66, y=1.96, z=-0.12
# Joint 24: x=0.31, y=1.97, z=0.13
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.67, z=-1.50
# Joint 11: x=0.71, y=0.92, z=-0.52
# Joint 12: x=0.18, y=1.01, z=-0.51
# Joint 13: x=1.02, y=0.55, z=-0.93
# Joint 14: x=0.02, y=1.46, z=-0.39
# Joint 23: x=0.66, y=1.95, z=-0.11
# Joint 24: x=0.31, y=1.96, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.67, z=-1.49
# Joint 11: x=0.71, y=0.92, z=-0.50
# Joint 12: x=0.18, y=1.01, z=-0.50
# Joint 13: x=1.02, y=0.56, z=-0.92
# Joint 14: x=0.03, y=1.48, z=-0.35
# Joint 23: x=0.65, y=1.95, z=-0.11
# Joint 24: x=0.30, y=1.96, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.47, y=0.67, z=-1.46
# Joint 11: x=0.70, y=0.95, z=-0.44
# Joint 12: x=0.18, y=1.01, z=-0.50
# Joint 13: x=0.97, y=0.64, z=-0.74
# Joint 14: x=0.04, y=1.53, z=-0.36
# Joint 23: x=0.65, y=1.95, z=-0.11
# Joint 24: x=0.30, y=1.96, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.46, y=0.67, z=-1.66
# Joint 11: x=0.70, y=0.97, z=-0.59
# Joint 12: x=0.17, y=1.02, z=-0.56
# Joint 13: x=0.98, y=0.71, z=-1.06
# Joint 14: x=0.01, y=1.49, z=-0.25
# Joint 23: x=0.65, y=1.99, z=-0.11
# Joint 24: x=0.29, y=2.01, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.46, y=0.67, z=-1.62
# Joint 11: x=0.70, y=0.97, z=-0.58
# Joint 12: x=0.17, y=1.02, z=-0.52
# Joint 13: x=0.98, y=0.71, z=-0.99
# Joint 14: x=0.01, y=1.48, z=-0.18
# Joint 23: x=0.65, y=1.99, z=-0.11
# Joint 24: x=0.29, y=2.00, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.26
# Joint 11: x=0.70, y=0.99, z=-0.26
# Joint 12: x=0.17, y=1.02, z=-0.26
# Joint 13: x=0.94, y=1.38, z=-0.36
# Joint 14: x=0.02, y=1.48, z=-0.16
# Joint 23: x=0.65, y=1.99, z=-0.11
# Joint 24: x=0.27, y=2.00, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.68, z=-1.24
# Joint 11: x=0.70, y=1.00, z=-0.24
# Joint 12: x=0.17, y=1.02, z=-0.23
# Joint 13: x=0.93, y=1.42, z=-0.35
# Joint 14: x=0.02, y=1.48, z=-0.17
# Joint 23: x=0.65, y=1.99, z=-0.11
# Joint 24: x=0.26, y=2.00, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.68, z=-1.10
# Joint 11: x=0.69, y=0.97, z=-0.20
# Joint 12: x=0.17, y=1.01, z=-0.24
# Joint 13: x=0.88, y=1.30, z=-0.40
# Joint 14: x=0.02, y=1.48, z=-0.39
# Joint 23: x=0.64, y=1.99, z=-0.11
# Joint 24: x=0.27, y=2.00, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.22
# Joint 11: x=0.69, y=0.98, z=-0.27
# Joint 12: x=0.17, y=1.01, z=-0.15
# Joint 13: x=0.82, y=1.36, z=-0.89
# Joint 14: x=0.04, y=1.45, z=-0.34
# Joint 23: x=0.64, y=1.98, z=-0.13
# Joint 24: x=0.27, y=2.00, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.23
# Joint 11: x=0.68, y=0.98, z=-0.29
# Joint 12: x=0.18, y=1.01, z=-0.12
# Joint 13: x=0.81, y=1.36, z=-0.93
# Joint 14: x=0.06, y=1.44, z=-0.32
# Joint 23: x=0.64, y=1.98, z=-0.14
# Joint 24: x=0.27, y=1.99, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.05
# Joint 11: x=0.68, y=0.99, z=-0.20
# Joint 12: x=0.17, y=1.01, z=-0.17
# Joint 13: x=0.82, y=1.45, z=-0.21
# Joint 14: x=0.05, y=1.49, z=-0.16
# Joint 23: x=0.63, y=1.93, z=-0.12
# Joint 24: x=0.26, y=1.93, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.12
# Joint 11: x=0.68, y=1.00, z=-0.24
# Joint 12: x=0.17, y=1.01, z=-0.25
# Joint 13: x=0.83, y=1.44, z=-0.34
# Joint 14: x=0.05, y=1.48, z=-0.20
# Joint 23: x=0.63, y=1.94, z=-0.11
# Joint 24: x=0.26, y=1.93, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.16
# Joint 11: x=0.68, y=1.00, z=-0.26
# Joint 12: x=0.17, y=1.01, z=-0.25
# Joint 13: x=0.84, y=1.44, z=-0.33
# Joint 14: x=0.05, y=1.48, z=-0.18
# Joint 23: x=0.63, y=1.94, z=-0.11
# Joint 24: x=0.26, y=1.93, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.21
# Joint 11: x=0.68, y=1.00, z=-0.27
# Joint 12: x=0.17, y=1.01, z=-0.26
# Joint 13: x=0.84, y=1.43, z=-0.30
# Joint 14: x=0.05, y=1.48, z=-0.18
# Joint 23: x=0.63, y=1.94, z=-0.11
# Joint 24: x=0.26, y=1.94, z=0.12
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.17
# Joint 11: x=0.68, y=1.01, z=-0.21
# Joint 12: x=0.17, y=1.01, z=-0.26
# Joint 13: x=0.84, y=1.45, z=-0.24
# Joint 14: x=0.05, y=1.52, z=-0.19
# Joint 23: x=0.63, y=1.95, z=-0.10
# Joint 24: x=0.26, y=1.95, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.68, z=-1.17
# Joint 11: x=0.68, y=1.01, z=-0.21
# Joint 12: x=0.17, y=1.01, z=-0.36
# Joint 13: x=0.83, y=1.44, z=-0.10
# Joint 14: x=0.05, y=1.51, z=-0.27
# Joint 23: x=0.62, y=1.94, z=-0.07
# Joint 24: x=0.25, y=1.95, z=0.08
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.25
# Joint 11: x=0.67, y=1.01, z=-0.21
# Joint 12: x=0.17, y=1.01, z=-0.42
# Joint 13: x=0.82, y=1.44, z=-0.11
# Joint 14: x=0.05, y=1.51, z=-0.32
# Joint 23: x=0.62, y=1.94, z=-0.06
# Joint 24: x=0.25, y=1.95, z=0.06
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.27
# Joint 11: x=0.67, y=1.01, z=-0.20
# Joint 12: x=0.17, y=1.01, z=-0.42
# Joint 13: x=0.82, y=1.44, z=-0.17
# Joint 14: x=0.05, y=1.50, z=-0.32
# Joint 23: x=0.62, y=1.94, z=-0.06
# Joint 24: x=0.25, y=1.95, z=0.06
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.27
# Joint 11: x=0.67, y=1.01, z=-0.21
# Joint 12: x=0.17, y=1.01, z=-0.39
# Joint 13: x=0.83, y=1.45, z=-0.17
# Joint 14: x=0.05, y=1.51, z=-0.30
# Joint 23: x=0.62, y=1.95, z=-0.06
# Joint 24: x=0.25, y=1.95, z=0.07
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.69, z=-1.26
# Joint 11: x=0.67, y=1.01, z=-0.20
# Joint 12: x=0.17, y=1.01, z=-0.36
# Joint 13: x=0.83, y=1.45, z=-0.21
# Joint 14: x=0.07, y=1.51, z=-0.25
# Joint 23: x=0.62, y=1.95, z=-0.06
# Joint 24: x=0.25, y=1.95, z=0.07
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.26
# Joint 11: x=0.67, y=1.01, z=-0.22
# Joint 12: x=0.17, y=1.01, z=-0.31
# Joint 13: x=0.85, y=1.44, z=-0.61
# Joint 14: x=0.04, y=1.49, z=-0.24
# Joint 23: x=0.62, y=1.96, z=-0.08
# Joint 24: x=0.25, y=1.97, z=0.09
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.26
# Joint 11: x=0.67, y=1.01, z=-0.24
# Joint 12: x=0.17, y=1.01, z=-0.30
# Joint 13: x=0.86, y=1.43, z=-0.58
# Joint 14: x=0.03, y=1.48, z=-0.22
# Joint 23: x=0.62, y=1.96, z=-0.09
# Joint 24: x=0.25, y=1.97, z=0.10
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.26
# Joint 11: x=0.67, y=1.01, z=-0.25
# Joint 12: x=0.17, y=1.01, z=-0.29
# Joint 13: x=0.86, y=1.43, z=-0.73
# Joint 14: x=0.04, y=1.48, z=-0.22
# Joint 23: x=0.62, y=1.96, z=-0.10
# Joint 24: x=0.25, y=1.97, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.68, z=-1.26
# Joint 11: x=0.67, y=1.01, z=-0.26
# Joint 12: x=0.17, y=1.01, z=-0.28
# Joint 13: x=0.86, y=1.43, z=-0.77
# Joint 14: x=0.05, y=1.48, z=-0.23
# Joint 23: x=0.62, y=1.96, z=-0.10
# Joint 24: x=0.25, y=1.97, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.43, y=0.69, z=-1.21
# Joint 11: x=0.68, y=1.02, z=-0.26
# Joint 12: x=0.17, y=1.01, z=-0.22
# Joint 13: x=0.86, y=1.47, z=-0.36
# Joint 14: x=0.05, y=1.50, z=-0.09
# Joint 23: x=0.62, y=1.97, z=-0.10
# Joint 24: x=0.25, y=1.97, z=0.11
# Data sent to Unity 🚀
# Joint 0: x=0.42, y=0.68, z=-1.33
# Joint 11: x=0.68, y=1.01, z=-0.34
# Joint 12: x=0.17, y=1.01, z=-0.23
# Joint 13: x=0.88, y=1.45, z=-0.56
# Joint 14: x=0.04, y=1.45, z=-0.01
# Joint 23: x=0.63, y=1.97, z=-0.13
# Joint 24: x=0.26, y=1.97, z=0.14
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.42
# Joint 11: x=0.68, y=1.01, z=-0.46
# Joint 12: x=0.17, y=1.01, z=-0.25
# Joint 13: x=0.88, y=1.44, z=-0.61
# Joint 14: x=0.04, y=1.45, z=0.06
# Joint 23: x=0.64, y=1.97, z=-0.14
# Joint 24: x=0.27, y=1.98, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.41, y=0.68, z=-1.43
# Joint 11: x=0.69, y=1.01, z=-0.47
# Joint 12: x=0.17, y=1.01, z=-0.27
# Joint 13: x=0.88, y=1.43, z=-0.60
# Joint 14: x=0.04, y=1.44, z=0.02
# Joint 23: x=0.65, y=1.97, z=-0.14
# Joint 24: x=0.28, y=1.99, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.68, z=-1.43
# Joint 11: x=0.69, y=1.01, z=-0.47
# Joint 12: x=0.17, y=1.01, z=-0.27
# Joint 13: x=0.89, y=1.43, z=-0.61
# Joint 14: x=0.03, y=1.44, z=0.05
# Joint 23: x=0.65, y=1.98, z=-0.14
# Joint 24: x=0.28, y=1.99, z=0.15
# Data sent to Unity 🚀
# Joint 0: x=0.40, y=0.68, z=-1.51
# Joint 11: x=0.71, y=1.00, z=-0.48
# Joint 12: x=0.17, y=1.01, z=-0.26
# Joint 13: x=0.91, y=1.39, z=-0.90
# Joint 14: x=0.02, y=1.41, z=-0.02
# Joint 23: x=0.66, y=1.96, z=-0.17
# Joint 24: x=0.28, y=1.98, z=0.18
# Data sent to Unity 🚀

# %%
import cv2
import mediapipe as mp
import numpy as np

# Load the anime face image (must be in same folder as this notebook)
face_img = cv2.imread('anime_face.png', cv2.IMREAD_UNCHANGED)

# Check if image is loaded
if face_img is None:
    print("❌ Error: Could not load 'anime_face.png'. Make sure it's in the same folder.")
    raise SystemExit

# Resize face image
face_img = cv2.resize(face_img, (100, 100))

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose()

# Open webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb)

    # Left view: original webcam
    left = frame.copy()

    # Right view: black background
    right = np.zeros_like(frame)

    if results.pose_landmarks:
        # Draw skeleton on right canvas
        mp_drawing.draw_landmarks(
            right,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=4, circle_radius=4),
            mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=4)
        )

        # Get the nose landmark (landmark index 0)
        landmarks = results.pose_landmarks.landmark
        h, w, _ = right.shape
        nose = landmarks[0]
        cx, cy = int(nose.x * w), int(nose.y * h)

        # Resize face image (already 100x100)
        face_h, face_w, _ = face_img.shape
        x1 = cx - face_w // 2
        y1 = cy - face_h // 2
        x2 = x1 + face_w
        y2 = y1 + face_h

        # Make sure face overlay is inside bounds
        if x1 >= 0 and y1 >= 0 and x2 <= w and y2 <= h:
            roi = right[y1:y2, x1:x2]
            face_rgb = face_img[:, :, :3]
            face_alpha = face_img[:, :, 3] / 255.0

            # Alpha blending face image over black background
            for c in range(3):
                roi[:, :, c] = roi[:, :, c] * (1 - face_alpha) + face_rgb[:, :, c] * face_alpha

            right[y1:y2, x1:x2] = roi

    # Combine left and right views
    combined = np.hstack((left, right))

    # Show side-by-side view
    cv2.imshow("🧍 You (Left) | 🎎 Anime Twin (Right)", combined)

    # Press 'q' to quit
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release everything
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp
import numpy as np

# Load your full anime body image (with transparency)
anime_img = cv2.imread('anime_body.png', cv2.IMREAD_UNCHANGED)

if anime_img is None:
    print("❌ Could not load 'anime_body.png'. Make sure it’s in the same folder.")
    raise SystemExit

# Resize your anime body image
anime_img = cv2.resize(anime_img, (200, 300))  # You can change size here

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Start webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb)

    # Left = original webcam
    left = frame.copy()

    # Right = empty black canvas
    right = np.zeros_like(frame)

    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark
        h, w, _ = right.shape

        # Use hip center to place anime body
        left_hip = landmarks[23]
        right_hip = landmarks[24]

        # Average of left and right hip
        cx = int(((left_hip.x + right_hip.x) / 2) * w)
        cy = int(((left_hip.y + right_hip.y) / 2) * h)

        # Overlay anime image at hip center
        img_h, img_w, _ = anime_img.shape
        x1 = cx - img_w // 2
        y1 = cy - img_h // 2
        x2 = x1 + img_w
        y2 = y1 + img_h

        if x1 >= 0 and y1 >= 0 and x2 <= w and y2 <= h:
            roi = right[y1:y2, x1:x2]
            char_rgb = anime_img[:, :, :3]
            char_alpha = anime_img[:, :, 3] / 255.0

            for c in range(3):
                roi[:, :, c] = roi[:, :, c] * (1 - char_alpha) + char_rgb[:, :, c] * char_alpha

            right[y1:y2, x1:x2] = roi

    # Combine both views
    combined = np.hstack((left, right))
    cv2.imshow("You (Left) | Anime Avatar (Right)", combined)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
